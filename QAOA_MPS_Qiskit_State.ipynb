# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, execute, BasicAer
import math
from matplotlib import pyplot as plt
import random
from scipy.optimize import minimize
from qiskit.circuit.library import RZZGate
import networkx as nx
from qiskit.providers.aer import StatevectorSimulator
from qiskit.quantum_info import Statevector

# %%
N = 8
graph=[(0, 1,1.0 ),(0, 2,2.0 ),(0, 3,5.0 ),(0, 5,1.0 ),(0, 6,3.0 ),(1, 3,2.0 ),(1, 6,1.0 ),(1, 7,4.0 ),
       (2, 4,1.0 ),(2, 6,1.0 ),(3, 4,2.0 ),(3, 6,3.0 ),(4, 5,1.0 ),(4, 6,1.0 ),(5, 6,2.0 ),(6, 7,1.0 )] 
G=nx.Graph()
G.add_weighted_edges_from(graph)
nx.draw(G,with_labels=True)

# %%
A=np.zeros((int(N),int(N)))
for i in graph:
    A[i[0]][i[1]] = i[2]
    A[i[1]][i[0]] = i[2]

# %%
def initialization(circuit):
    for qubit in circuit.qubits:
        circuit.h(qubit)
    return circuit

# %%
def cost_unitary_layer(circuit,gamma):
    for edge in graph:
        if edge[1] == edge[0] + 1:
            circuit.append(RZZGate(gamma*edge[2]),[edge[0],edge[0]+1])
        if edge[1] != edge[0] + 1:
            circuit.swap(edge[1],edge[0]+1)
            circuit.append(RZZGate(gamma*edge[2]),[edge[0],edge[0]+1])
            circuit.swap(edge[1],edge[0]+1)
    circuit.barrier()
    return circuit

# %%
def mixture_unitary_layer(circuit,alpha):
    for qubit in circuit.qubits:
        circuit.rx(alpha,qubit)
    circuit.barrier()
    return circuit

# %%
def create_params(params):
    alphas = []
    gammas = []
    for i in range(int(len(params)/2)):
        gammas.append(params[2*i])
        alphas.append(params[2*i+1])
    return gammas , alphas

# %%
def anasatz(params):
    gammas, alphas = create_params(params)
    q = QuantumRegister(N)
    c = ClassicalRegister(N)
    circuit = QuantumCircuit(q,c)
    circuit = initialization(circuit)
    for i in range(n_layers):
        circuit = cost_unitary_layer(circuit, gammas[i])
        circuit = mixture_unitary_layer(circuit,alphas[i])
    #circuit.measure(circuit.qubits,c)
    
    
    simulator = StatevectorSimulator()
    result = execute(circuit,simulator).result()
    sv = result.get_statevector(circuit)
    states = Statevector(sv)
    counts = states.probabilities_dict(decimals=3)
    for key in counts.keys():
        counts[key] = int(1000*counts[key])
        
        
    results = counts.keys()
    new_res=[]
    for key in results:
        hold=[]
        for i in range(0,len(key)):
            hold.append(int(key[i]))
        for i in range(0,counts[key]):
            new_res.append(hold)
    return circuit,counts,new_res

# %%
n_layers = 1
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]

# %%
circuit,counts,new_res = anasatz(params)

# %%
circuit.draw('mpl')

# %%
def cost_function(params):
    circuit,counts,result = anasatz(params)
    total_cost = 0
    for i in range(len(result)):
        for edge in graph:
            total_cost += (A[edge[0]][edge[1]])*(1-2*result[i][edge[0]])*(1-2*result[i][edge[1]]) + (A[edge[1]][edge[0]])*(1-2*result[i][edge[1]])*(1-2*result[i][edge[0]])
    total_cost = total_cost/1024
    print("Cost: "+str(total_cost))
    return total_cost

# %%
import seaborn as sns
collect_counts = []
collect_costs = []
n_layers = 1
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :1
# Cost: -1.75390625
# Cost: 3.41015625
# Cost: -0.02734375
# Cost: 6.74609375
# Cost: -3.6953125
# Cost: 8.921875
# Cost: -3.328125
# Cost: 2.65234375
# Cost: -0.19140625
# Cost: -2.30078125
# Cost: -3.5546875
# Cost: -3.56640625
# Cost: -3.39453125
# Cost: -3.625
# Cost: -3.83203125
# Cost: -3.69921875
# Cost: -3.86328125
# Cost: -3.7890625
# Cost: -3.86328125
# Cost: -3.86328125
# Cost: -3.86328125
# Cost: -3.86328125
# Cost: -3.86328125
# Cost: -3.86328125
# Out:      fun: -3.86328125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 24
#   status: 1
#  success: True
#        x: array([ 0.64859596, -1.345056  ])
# Z with maximum frequency is  :203

# %%
n_layers = 2
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :2
# Cost: -0.39453125
# Cost: 1.19140625
# Cost: 3.94921875
# Cost: 1.1484375
# Cost: 3.734375
# Cost: 4.7578125
# Cost: 1.3984375
# Cost: 1.33203125
# Cost: -0.82421875
# Cost: 0.4140625
# Cost: 0.9765625
# Cost: -1.41796875
# Cost: -0.66796875
# Cost: -0.85546875
# Cost: -1.49609375
# Cost: -2.3828125
# Cost: -3.0625
# Cost: -3.00390625
# Cost: -3.109375
# Cost: -3.27734375
# Cost: -3.34765625
# Cost: -3.3515625
# Cost: -3.328125
# Cost: -2.87890625
# Cost: -3.5078125
# Cost: -3.58203125
# Cost: -3.44140625
# Cost: -3.1796875
# Cost: -3.4296875
# Cost: -3.49609375
# Cost: -3.546875
# Cost: -3.40234375
# Cost: -3.62890625
# Cost: -3.41796875
# Cost: -3.609375
# Cost: -3.53125
# Cost: -3.62890625
# Cost: -3.40625
# Cost: -3.42578125
# Cost: -3.6328125
# Cost: -3.64453125
# Cost: -3.6171875
# Cost: -3.64453125
# Cost: -3.62109375
# Cost: -3.64453125
# Cost: -3.62890625
# Cost: -3.6328125
# Cost: -3.6171875
# Cost: -3.64453125
# Cost: -3.64453125
# Cost: -3.64453125
# Cost: -3.64453125
# Cost: -3.64453125
# Out:      fun: -3.64453125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 53
#   status: 1
#  success: True
#        x: array([-2.64389543, -1.72273175, -0.00842869,  2.41681495])
# Z with maximum frequency is  :237

# %%
n_layers = 3
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :3
# Cost: 1.8359375
# Cost: 1.25
# Cost: 4.9375
# Cost: 1.71484375
# Cost: 0.3515625
# Cost: 1.1640625
# Cost: -1.86328125
# Cost: -1.82421875
# Cost: 0.765625
# Cost: -5.21875
# Cost: -2.10546875
# Cost: -4.90234375
# Cost: -2.41015625
# Cost: -3.8984375
# Cost: -4.5546875
# Cost: -3.890625
# Cost: -4.95703125
# Cost: -6.6484375
# Cost: -5.27734375
# Cost: -6.37109375
# Cost: -6.01953125
# Cost: -6.31640625
# Cost: -5.73828125
# Cost: -7.078125
# Cost: -6.70703125
# Cost: -7.2734375
# Cost: -7.2265625
# Cost: -7.3203125
# Cost: -7.76171875
# Cost: -8.1171875
# Cost: -8.296875
# Cost: -7.79296875
# Cost: -8.27734375
# Cost: -8.07421875
# Cost: -7.8125
# Cost: -8.1015625
# Cost: -8.30078125
# Cost: -8.44140625
# Cost: -8.40234375
# Cost: -8.2421875
# Cost: -8.11328125
# Cost: -8.2109375
# Cost: -8.27734375
# Cost: -8.34765625
# Cost: -8.3359375
# Cost: -8.33984375
# Cost: -8.44140625
# Cost: -8.453125
# Cost: -8.4453125
# Cost: -8.39453125
# Cost: -8.4375
# Cost: -8.3984375
# Cost: -8.453125
# Cost: -8.46484375
# Cost: -8.4375
# Cost: -8.46484375
# Cost: -8.48828125
# Cost: -8.4453125
# Cost: -8.4609375
# Cost: -8.46484375
# Cost: -8.48828125
# Cost: -8.44140625
# Cost: -8.4609375
# Cost: -8.453125
# Cost: -8.4609375
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Cost: -8.48828125
# Out:      fun: -8.48828125
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 75
#   status: 1
#  success: True
#        x: array([ 0.48007776, -1.22349096,  2.85768942,  2.77351485,  0.81501882,
#         0.46877302])
# Z with maximum frequency is  :145

# %%
n_layers = 4
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :4
# Cost: 2.6484375
# Cost: -0.76953125
# Cost: 0.17578125
# Cost: 0.875
# Cost: 1.66015625
# Cost: 1.76171875
# Cost: -0.953125
# Cost: 0.015625
# Cost: 5.00390625
# Cost: 0.9921875
# Cost: -1.78515625
# Cost: -0.25
# Cost: 0.62890625
# Cost: -0.6953125
# Cost: -1.43359375
# Cost: -1.25390625
# Cost: 0.08984375
# Cost: -1.640625
# Cost: -0.5078125
# Cost: -0.54296875
# Cost: -0.86328125
# Cost: -1.10546875
# Cost: -2.37890625
# Cost: -2.7109375
# Cost: -2.796875
# Cost: -1.953125
# Cost: -3.30078125
# Cost: -3.26953125
# Cost: -3.0390625
# Cost: -2.81640625
# Cost: -2.86328125
# Cost: -3.1171875
# Cost: -3.06640625
# Cost: -2.55078125
# Cost: -2.89453125
# Cost: -3.46484375
# Cost: -3.1484375
# Cost: -3.5703125
# Cost: -3.4765625
# Cost: -3.46484375
# Cost: -3.4453125
# Cost: -3.6953125
# Cost: -3.53515625
# Cost: -3.41796875
# Cost: -3.1328125
# Cost: -3.51953125
# Cost: -3.609375
# Cost: -3.62109375
# Cost: -3.4921875
# Cost: -3.56640625
# Cost: -3.63671875
# Cost: -3.46484375
# Cost: -3.390625
# Cost: -3.671875
# Cost: -3.62109375
# Cost: -3.66015625
# Cost: -3.65234375
# Cost: -3.6640625
# Cost: -3.66796875
# Cost: -3.609375
# Cost: -3.65625
# Cost: -3.69921875
# Cost: -3.70703125
# Cost: -3.68359375
# Cost: -3.70703125
# Cost: -3.66015625
# Cost: -3.7109375
# Cost: -3.66796875
# Cost: -3.6953125
# Cost: -3.640625
# Cost: -3.69921875
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.68359375
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.69921875
# Cost: -3.7109375
# Cost: -3.6953125
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.7109375
# Cost: -3.7109375
# Out:      fun: -3.7109375
#    maxcv: 0.0
#  message: 'Optimization terminated successfully.'
#     nfev: 85
#   status: 1
#  success: True
#        x: array([ 2.62453949, -1.2921659 , -2.97672321,  1.10640031,  1.53880235,
#        -0.87355433,  0.76852355,  1.07868236])
# Z with maximum frequency is  :175

# %%
n_layers = 5
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :5
# Cost: 1.7734375
# Cost: 3.16015625
# Cost: 3.29296875
# Cost: 1.734375
# Cost: 2.2734375
# Cost: 0.33984375
# Cost: -0.74609375
# Cost: 3.125
# Cost: -2.30078125
# Cost: -1.2109375
# Cost: 8.03125
# Cost: -0.8984375
# Cost: -3.72265625
# Cost: 2.7265625
# Cost: -0.6015625
# Cost: -0.46875
# Cost: -0.171875
# Cost: -2.5234375
# Cost: 0.796875
# Cost: -2.984375
# Cost: -1.3671875
# Cost: -3.140625
# Cost: -4.64453125
# Cost: -4.4375
# Cost: 12.26953125
# Cost: -1.60546875
# Cost: 0.2578125
# Cost: -2.91015625
# Cost: -4.90234375
# Cost: -3.7109375
# Cost: -2.18359375
# Cost: -4.45703125
# Cost: -4.65625
# Cost: -4.56640625
# Cost: -4.96875
# Cost: -3.89453125
# Cost: -5.19140625
# Cost: -4.62890625
# Cost: -4.15625
# Cost: -5.05859375
# Cost: -5.1171875
# Cost: -5.15234375
# Cost: -4.5546875
# Cost: -4.9296875
# Cost: -5.67578125
# Cost: -1.4609375
# Cost: -5.46484375
# Cost: -5.2734375
# Cost: -5.46484375
# Cost: -3.09375
# Cost: -5.4453125
# Cost: -5.640625
# Cost: -5.5859375
# Cost: -5.39453125
# Cost: -5.5
# Cost: -5.6640625
# Cost: -5.72265625
# Cost: -5.46484375
# Cost: -5.71875
# Cost: -5.95703125
# Cost: -5.83984375
# Cost: -5.84765625
# Cost: -6.09765625
# Cost: -6.140625
# Cost: -6.1640625
# Cost: -6.03125
# Cost: -6.0859375
# Cost: -6.0625
# Cost: -5.89453125
# Cost: -6.01953125
# Cost: -6.0703125
# Cost: -5.95703125
# Cost: -6.1484375
# Cost: -6.15234375
# Cost: -6.1640625
# Cost: -6.16796875
# Cost: -5.91015625
# Cost: -6.12890625
# Cost: -5.8671875
# Cost: -6.01171875
# Cost: -6.16796875
# Cost: -6.09765625
# Cost: -6.09765625
# Cost: -6.12109375
# Cost: -6.0546875
# Cost: -6.01953125
# Cost: -5.96484375
# Cost: -6.0546875
# Cost: -6.0625
# Cost: -6.0390625
# Cost: -6.16796875
# Cost: -6.1171875
# Cost: -6.20703125
# Cost: -6.03515625
# Cost: -6.140625
# Cost: -6.05859375
# Cost: -6.08984375
# Cost: -6.078125
# Cost: -6.08984375
# Cost: -6.1171875
# Out:      fun: -6.20703125
#    maxcv: 0.0
#  message: 'Maximum number of function evaluations has been exceeded.'
#     nfev: 100
#   status: 2
#  success: False
#        x: array([-1.68976995,  0.01068252, -0.06354078,  2.93242537,  3.37097443,
#         3.02665883,  1.30552629,  2.59235796,  2.69607238,  1.31124314])
# Z with maximum frequency is  :203

# %%
n_layers = 6
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :6
# Cost: 0.1015625
# Cost: 1.46484375
# Cost: 0.28515625
# Cost: -0.80078125
# Cost: 0.96875
# Cost: -0.43359375
# Cost: 0.55859375
# Cost: -0.1796875
# Cost: -1.359375
# Cost: -0.53515625
# Cost: 0.796875
# Cost: -0.55859375
# Cost: -0.734375
# Cost: 0.734375
# Cost: -0.11328125
# Cost: -2.109375
# Cost: -1.3046875
# Cost: 0.421875
# Cost: 0.37890625
# Cost: -1.94921875
# Cost: -0.69921875
# Cost: -1.99609375
# Cost: -2.05859375
# Cost: -1.203125
# Cost: -1.390625
# Cost: -0.58984375
# Cost: -2.37109375
# Cost: -3.13671875
# Cost: -2.828125
# Cost: -0.3515625
# Cost: -0.83203125
# Cost: -0.34765625
# Cost: -2.46875
# Cost: -3.28125
# Cost: -3.02734375
# Cost: -2.4296875
# Cost: -2.8046875
# Cost: -3.35546875
# Cost: -1.671875
# Cost: -2.703125
# Cost: -3.83984375
# Cost: -4.01171875
# Cost: -3.2578125
# Cost: -4.23046875
# Cost: -4.30859375
# Cost: -4.26171875
# Cost: -3.21875
# Cost: -3.9453125
# Cost: -3.97265625
# Cost: -4.0078125
# Cost: -4.8046875
# Cost: -4.6328125
# Cost: -3.98828125
# Cost: -4.421875
# Cost: -4.171875
# Cost: -4.84765625
# Cost: -4.39453125
# Cost: -4.34375
# Cost: -4.734375
# Cost: -5.1015625
# Cost: -4.92578125
# Cost: -5.05078125
# Cost: -5.0625
# Cost: -4.9140625
# Cost: -5.140625
# Cost: -5.54296875
# Cost: -5.609375
# Cost: -5.66015625
# Cost: -5.35546875
# Cost: -5.5625
# Cost: -5.33203125
# Cost: -5.8203125
# Cost: -5.671875
# Cost: -5.640625
# Cost: -5.47265625
# Cost: -5.70703125
# Cost: -5.7421875
# Cost: -5.828125
# Cost: -5.73046875
# Cost: -5.984375
# Cost: -6.03515625
# Cost: -5.84375
# Cost: -5.7890625
# Cost: -5.8125
# Cost: -6.25390625
# Cost: -5.94921875
# Cost: -6.2578125
# Cost: -5.7265625
# Cost: -6.34375
# Cost: -6.109375
# Cost: -6.29296875
# Cost: -6.1484375
# Cost: -6.0625
# Cost: -6.26953125
# Cost: -6.15625
# Cost: -6.21875
# Cost: -6.2265625
# Cost: -6.3359375
# Cost: -6.1171875
# Cost: -6.2109375
# Out:      fun: -6.34375
#    maxcv: 0.0
#  message: 'Maximum number of function evaluations has been exceeded.'
#     nfev: 100
#   status: 2
#  success: False
#        x: array([ 1.23479262,  1.66630328,  2.91885086, -0.94089679,  2.98094061,
#         1.18525308, -3.01272045,  1.91365422,  1.44702825,  1.93050548,
#        -2.40280393, -2.64317121])
# Z with maximum frequency is  :137

# %%
n_layers = 7
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :7
# Cost: -1.875
# Cost: 1.3515625
# Cost: 0.6953125
# Cost: 1.56640625
# Cost: -2.703125
# Cost: 3.49609375
# Cost: 2.0234375
# Cost: -1.0390625
# Cost: -1.19921875
# Cost: -1.91796875
# Cost: -0.09375
# Cost: -2.171875
# Cost: 0.14453125
# Cost: 1.32421875
# Cost: -0.5703125
# Cost: -0.16015625
# Cost: -1.61328125
# Cost: 2.25
# Cost: 2.1328125
# Cost: -0.91796875
# Cost: -2.51171875
# Cost: -2.29296875
# Cost: -2.3046875
# Cost: -2.20703125
# Cost: -1.17578125
# Cost: -2.09375
# Cost: -1.5703125
# Cost: -2.23046875
# Cost: -1.921875
# Cost: -0.66015625
# Cost: -1.75390625
# Cost: -0.26953125
# Cost: -0.09765625
# Cost: -2.41796875
# Cost: -1.85546875
# Cost: -2.5078125
# Cost: -2.82421875
# Cost: -3.015625
# Cost: -2.8984375
# Cost: -2.97265625
# Cost: -2.8359375
# Cost: -2.3515625
# Cost: -2.37890625
# Cost: -3.3046875
# Cost: -3.109375
# Cost: -3.23046875
# Cost: -2.72265625
# Cost: -3.1171875
# Cost: -3.03125
# Cost: -3.10546875
# Cost: -2.8203125
# Cost: -2.72265625
# Cost: -3.1796875
# Cost: -3.078125
# Cost: -3.33984375
# Cost: -3.2578125
# Cost: -3.23046875
# Cost: -3.25
# Cost: -3.21484375
# Cost: -3.3046875
# Cost: -3.359375
# Cost: -3.3359375
# Cost: -3.1015625
# Cost: -3.10546875
# Cost: -3.0625
# Cost: -3.15625
# Cost: -3.09375
# Cost: -3.13671875
# Cost: -3.09765625
# Cost: -3.07421875
# Cost: -3.21484375
# Cost: -3.17578125
# Cost: -2.98828125
# Cost: -3.28515625
# Cost: -3.32421875
# Cost: -3.234375
# Cost: -3.26171875
# Cost: -3.33203125
# Cost: -3.1328125
# Cost: -3.22265625
# Cost: -3.26953125
# Cost: -3.1640625
# Cost: -3.234375
# Cost: -3.29296875
# Cost: -3.33203125
# Cost: -3.26953125
# Cost: -3.359375
# Cost: -3.26953125
# Cost: -3.33203125
# Cost: -3.2578125
# Cost: -3.32421875
# Cost: -3.33203125
# Cost: -3.28125
# Cost: -3.359375
# Cost: -3.32421875
# Cost: -3.359375
# Cost: -3.359375
# Cost: -3.359375
# Cost: -3.359375
# Cost: -3.33203125
# Out:      fun: -3.359375
#    maxcv: 0.0
#  message: 'Maximum number of function evaluations has been exceeded.'
#     nfev: 100
#   status: 2
#  success: False
#        x: array([-1.99580113, -2.61368144,  1.36116729,  0.9777945 ,  1.1823395 ,
#         1.88784219, -2.62872692, -2.41309248,  2.08615162,  0.20659222,
#         0.65755874, -0.97884901,  1.78618731, -2.49106599])
# Z with maximum frequency is  :145

# %%
len(collect_counts)
# Out:
# 7

# %%
n_layers = 8
params = [float(random.randint(-314, 314))/float(100) for i in range(0, 2*n_layers)]
num_iters = 100
print("optimization for depth :{}".format(n_layers))
out = minimize(cost_function, x0=params, method="COBYLA", options={'maxiter':num_iters})
print(f'Out: {out}')
circuit,counts,result = anasatz(out['x'])
collect_counts.append(counts)
collect_costs.append(out.fun)

x=[]
y=[]
for key in counts.keys():
    num = 0
    
    for i in range(len(key)):
        num = num + pow(2,i)*int(key[len(key)-1-i])
    x.append(num)
    y.append(counts[key])
    if counts[key] == max(y):
        maximum = num
sns.set()
plt.bar(x,y,color='b', width = 4)
plt.xlabel("z")
plt.ylabel("frequency")
plt.show()
print("Z with maximum frequency is  :{}".format(maximum))
# Out:
# optimization for depth :8
# Cost: 1.12109375
# Cost: 0.72265625
# Cost: -2.5859375
# Cost: -0.23046875
# Cost: -2.71484375
# Cost: -1.859375
# Cost: -2.37109375
# Cost: -0.609375
# Cost: -3.05859375
# Cost: 1.76953125
# Cost: -4.01953125
# Cost: -2.47265625
# Cost: -0.33203125
# Cost: -1.06640625
# Cost: -0.4140625
# Cost: -1.31640625
# Cost: -3.46484375
# Cost: -0.8203125
# Cost: 1.9921875
# Cost: 3.3046875
# Cost: -1.65625
# Cost: -1.796875
# Cost: -0.74609375
# Cost: -4.02734375
# Cost: 2.92578125
# Cost: -4.28125
# Cost: -0.73828125
# Cost: -1.90625
# Cost: 0.87890625
# Cost: -3.48046875
# Cost: -3.3046875
# Cost: -4.1796875
# Cost: -0.12109375
# Cost: -3.3828125
# Cost: -1.73828125
# Cost: -4.17578125
# Cost: -2.3359375
# Cost: -1.90625
# Cost: -0.88671875
# Cost: 1.51171875
# Cost: -0.828125
# Cost: -4.96484375
# Cost: -5.01953125
# Cost: -1.3515625
# Cost: -4.66015625
# Cost: -5.2890625
# Cost: -5.5546875
# Cost: -5.2421875
# Cost: -4.77734375
# Cost: -4.625
# Cost: -5.5546875
# Cost: -4.32421875
# Cost: -5.33203125
# Cost: -4.49609375
# Cost: -5.45703125
# Cost: -5.453125
# Cost: -5.51171875
# Cost: -3.34765625
# Cost: -5.07421875
# Cost: -4.9453125
# Cost: -5.234375
# Cost: -3.25390625
# Cost: -4.9140625
# Cost: -5.38671875
# Cost: -5.53125
# Cost: -5.60546875
# Cost: -4.90625
# Cost: -5.5859375
# Cost: -5.53515625
# Cost: -5.3125
# Cost: -5.328125
# Cost: -5.8515625
# Cost: -5.5859375
# Cost: -5.73828125
# Cost: -5.3359375
# Cost: -5.796875
# Cost: -5.6640625
# Cost: -5.75
# Cost: -5.58984375
# Cost: -5.671875
# Cost: -5.6328125
# Cost: -5.57421875
# Cost: -5.67578125
# Cost: -5.5546875
# Cost: -5.46875
# Cost: -5.609375
# Cost: -5.6953125
# Cost: -5.69921875
# Cost: -5.5859375
# Cost: -5.828125
# Cost: -5.796875
# Cost: -5.8359375
# Cost: -5.80078125
# Cost: -5.83984375
# Cost: -5.84375
# Cost: -5.92578125
# Cost: -5.83203125
# Cost: -5.63671875
# Cost: -5.81640625
# Cost: -5.80078125
# Out:      fun: -5.92578125
#    maxcv: 0.0
#  message: 'Maximum number of function evaluations has been exceeded.'
#     nfev: 100
#   status: 2
#  success: False
#        x: array([-0.96964006, -0.93893069, -0.32987794,  1.82275925, -2.06217383,
#        -0.11604122, -2.22894554,  3.33743576,  2.08998878,  1.16836758,
#        -2.04820173,  1.9790936 ,  1.75548697,  2.53615645,  2.23548094,
#        -1.06991419])
# Z with maximum frequency is  :131

# %%
x = [1,2,3,4,5,6,7,8]
y = collect_costs
plt.plot(x,y)
plt.xlabel("layers")
plt.ylabel("costs")
plt.show()

# %%
best_cost_brute = 0
for b in range(2**N):
    x = [int(t) for t in reversed(list(bin(b)[2:].zfill(N)))]
    cost = 0
    for i in range(N):
        for j in range(N):
            cost = cost + A[i,j]*x[i]*(1-x[j])
    if best_cost_brute < cost:
        best_cost_brute = cost
        xbest_brute = x
    #print('case = ' + str(x)+ ' cost = ' + str(cost))

colors = ['r' if xbest_brute[i] == 0 else 'c' for i in range(N)]

print('\nBest solution = ' + str(xbest_brute) + ' cost = ' + str(best_cost_brute))
# Out:
# Best solution = [1, 1, 0, 0, 1, 0, 1, 0] cost = 25.0
